# %% [markdown]
# # PACKAGES

# %%
import pandas as pd
import contextily as cx
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
import numpy as np
from scipy.spatial.distance import cdist
from shapely.ops import cascaded_union
from shapely.ops import unary_union
import geovoronoi as gv
import geovoronoi.plotting as gvplt
import seaborn as sns
from shapely.geometry import Polygon
from sklearn.neighbors import BallTree

# %% [markdown]
# # DATA COLLECTION

# %%
masterlist_filename = 'landbank.json'

# %%
def nearby(ind, dist, df, branch_index):
    listing = ind[j]
    for indx, i in enumerate(listing):
        prnt_dist = dist[j][indx]*earth_radius
        print('%.0fm'%prnt_dist, df.at[i, 'type_id'], 
          df.at[i, 'address'], df.at[i, 'latitude'], df.at[i, 'longitude'], i, df.at[i, 'id'])
    return 0

# %%
df = pd.read_json(masterlist_filename)
df = df.T
df.sort_index(inplace=True)
df.at[13, 'latitude'] = '15.308691'
df.at[460, 'latitude'] = '14.6507700'
df.at[460, 'longitude'] = '120.9721620'
df.at[610, 'latitude'] = '14.6492420'
df.at[610, 'longitude'] = '121.0692769'
df.at[5551, 'latitude'] = '15.5328227'
df.at[5551, 'longitude'] = '119.9570529'
df.drop(df[df.status_id == 0].index, inplace=True)
df.reset_index(inplace=True)

# %%
known = [477, 0, 2316, 168, 55]
type_id_label = {1: 'branch and branch-lite', 2: 'LEAF', 3: 'atm', 4: 'cash-deposit machines', 5: 'lending center'}
#411Branches and 66 branch-lite units, 55 Lending Centers and 2,316 ATMs and 168 CDMs 
for i in range(1,6):
    print(i, df[df.type_id ==i].shape, known[i-1])
# Out:
# 1 (449, 20) 477
# 2 (47, 20) 0
# 3 (2150, 20) 2316
# 4 (120, 20) 168
# 5 (57, 20) 55

# %%
print(df.shape)
df.tail(5)
# Out:
# (2823, 20)
#       index    id fid maker_id checker_id type_id region_id province_id  \
# 2818   5542  5542   0       28          9       1         7          37
# 2819   5546  5546   0       28          9       1         7          38
# 2820   5549  5549   0       28          9       1        11          55
# 2821   5551  5551   0       28          0       1         3          16
# 2822   5552  5552   0       28          0       1         8          39
#
#      city_id status_id                                name  \
# 2818     682         1    Barotac Viejo (Iloilo)  Agri Hub
# 2819    1039         1              Himamaylan Branch Lite
# 2820     984         1  Tangub (Misamis Occidental) Branch
# 2821    1552         2          Masinloc (Zambales) Branch
# 2822     269         2              Tubigon (Bohol) Branch
#
#                                                 address  \
# 2818  Barotac Viejo Trade Center, Zulueta Drive, Bar...
# 2819  GM Building, Rizal Street, Barangay 2, Poblaci...
# 2820  2nd North corner Magsaysay Street, Barangay II...
# 2821  National Highway, Barangay Inhobol, Masinloc, ...
# 2822  B. Cabangbang Avenue, Barangay Potohan, Tubigo...
#
#                                 email           number   fax    longitude  \
# 2818    AGRI_BVIEJO@mail.landbank.com   (033) 337-3632  None  122.8497443
# 2819  BR_HIMAMAYLAN@mail.landbank.com   (034) 388-3777  None  122.9665772
# 2820      BR_TANGUB@mail.landbank.com   (088) 531-3113  None  123.7500494
# 2821    BR_MASINLOC@mail.landbank.com  (0966) 239-5481  None  119.9570529
# 2822     BR_TUBIGON@mail.landbank.com   (038) 237-2658  None  123.9484996
#
#         latitude remarks           created_at           updated_at
# 2818  11.0392085    None  2021-02-26 14:48:01  2021-03-05 09:13:38
# 2819  10.2054372    None  2021-02-26 15:17:50  2021-03-05 09:35:47
# 2820   8.0635912    None  2021-02-26 15:37:21  2021-03-05 09:39:18
# 2821  15.5328227    None  2021-03-05 15:00:45  2021-03-05 15:00:45
# 2822   9.9360606    None  2021-03-05 15:11:42  2021-03-05 15:11:42

# %%
df[df.type_id == 2].id
df[df.id == 5508]
df[df.city_id == 774]
# Out:
#       index    id fid maker_id checker_id type_id region_id province_id  \
# 2017   2181  2181   0       50         68       4         1           3
# 2188   2683  2683   0       50         68       3         1           3
# 2800   5508  5508   0       28          9       2         1           3
#
#      city_id status_id                  name                          address  \
# 2017     774         1         CDM LEAF Pugo  'Poblacion West, Pugo, La Union
# 2188     774         1             LEAF Pugo   Poblacion West, Pugo, La Union
# 2800     774         1  Pugo (La Union) LEAF   Poblacion West, Pugo, La Union
#
#                             email                  number   fax    longitude  \
# 2017                          N/A                     N/A   N/A  120.4677679
# 2188                         None                     N/A   N/A  120.4656775
# 2800  leaf_pugo@mail.landbank.com  (0917) (0917)-503-7581  None  120.4764692
#
#         latitude remarks           created_at           updated_at
# 2017  16.3123097    None  2019-09-24 16:39:51  2019-09-25 10:29:46
# 2188  16.3203602    None  2019-09-25 14:48:33  2019-09-27 16:35:41
# 2800  16.3195419    None  2019-10-03 17:08:19  2019-10-03 17:16:06

# %%
print(len(df['province_id'].unique()), len(df['city_id'].unique()))
# Out:
# 81 692

# %%
long = df['longitude'].astype(float)
lat = df['latitude'].astype(float)
geometry = [Point(xy) for xy in zip(long, lat)]
geo_df = gpd.GeoDataFrame(geometry = geometry)
geo_df = geo_df.set_crs(epsg=4326)

#geo_df.crs = {'init':"epsg:4326"}

# %%
# ax = geo_df.plot(color="red", markersize=0.2, figsize=(20, 20))
# #cx.add_basemap(ax, crs=geo_df.crs.to_string())
# # plot the marker
# cx.add_basemap(ax, crs=geo_df.crs.to_string(), source=cx.providers.OpenStreetMap.Mapnik)

# %%
# nightlights = cx.providers.NASAGIBS.ViirsEarthAtNight2012
# philippines = cx.Place("Philippines", source=nightlights)
# philippines.plot()

# %%
df[df['city_id'] == 17] #14 QC
# Out:
#       index    id fid maker_id checker_id type_id region_id province_id  \
# 41       43    43   0       28          9       1        16          77
# 415     417   417   0       50         68       3        16          77
# 417     419   419   0       50         68       3        16          77
# 418     420   420   0       50         68       3        16          77
# 420     422   422   0       50         68       3        16          77
# 1950   2110  2110   0       50         68       3        16          77
# 1951   2111  2111   0       50         68       3        16          77
# 1952   2112  2112   0       50         68       3        16          77
# 1953   2113  2113   0       50         68       3        16          77
# 1954   2114  2114   0       50         68       3        16          77
# 1955   2115  2115   0       50         68       3        16          77
#
#      city_id status_id                           name  \
# 41        17         1              Valenzuela Branch
# 415       17         1      Valenzuela Medical Center
# 417       17         1               Valenzuela LGU 2
# 418       17         1               Valenzuela LGU 1
# 420       17         1                     Valenzuela
# 1950      17         1                 Brgy. Punturin
# 1951      17         1              3S Center Marulas
# 1952      17         1                    Brgy. Ugong
# 1953      17         1               Brgy. GT De Leon
# 1954      17         1  Finance Center Valenzuela LGU
# 1955      17         1       Dalandanan Action Center
#
#                                                 address  \
# 41    ARCA North Corporate Center Building #150 F. D...
# 415         Padrigal Street, Karuhatan, Valenzuela City
# 417          Valenzuela LGU, Poblacion, Valenzuela City
# 418          Valenzuela LGU, Poblacion, Valenzuela City
# 420   GBT Bldg. Oreta Subd., Maysan Road corner G. T...
# 1950  Valenzuela LGU's 3S Center 150 P. Faustino St....
# 1951          3S Center, Brgy. Marulas, Valenzuela City
# 1952  3S Center Brgy Ugong,GF Que Grande St. Ugong, ...
# 1953  3S Center M. Delos Reyes, Brgy Gen. T De Leon,...
# 1954             Mc Arthur Highway, Malinta, Valenzuela
# 1955   Action Center, Brgy. Dalandanan, Valenzuela City
#
#                               email                              number  \
# 41    BR_VLNZUELA@mail.landbank.com  (02) 8292-1971;8292-3688;8292-0114
# 415                             N/A                                 N/A
# 417                             N/A                                 N/A
# 418                             N/A                                 N/A
# 420                             N/A                                 N/A
# 1950                           None                                 N/A
# 1951                           None                                 N/A
# 1952                           None                                 N/A
# 1953                           None                                 N/A
# 1954                           None                                 N/A
# 1955                           None                                 N/A
#
#                  fax           longitude            latitude remarks  \
# 41    (02) 8292-1478  120.98321758320519  14.701266365738643    None
# 415              N/A         120.8990212           14.692362    None
# 417              N/A         120.9605635           14.689741    None
# 418              N/A         120.9605635           14.689741    None
# 420              N/A          120.969059           14.692362    None
# 1950             N/A         120.9878149          14.7410312    None
# 1951             N/A         120.9806544          14.6739805    None
# 1952             N/A         121.0069227          14.6941205    None
# 1953             N/A         120.9887583          14.6853377    None
# 1954             N/A         120.9668703          14.6923672    None
# 1955             N/A         120.9603042          14.6923929    None
#
#                created_at           updated_at
# 41    2019-06-18 17:04:37  2021-03-05 09:11:25
# 415   2019-06-20 13:29:18  2019-09-27 13:42:47
# 417   2019-06-20 13:30:38  2019-09-27 13:42:42
# 418   2019-06-20 13:31:32  2019-09-27 13:41:56
# 420   2019-06-20 13:33:46  2019-09-27 13:41:50
# 1950  2019-09-24 15:09:18  2019-09-27 13:42:01
# 1951  2019-09-24 15:10:28  2019-09-27 13:42:22
# 1952  2019-09-24 15:11:12  2019-09-27 13:42:27
# 1953  2019-09-24 15:12:16  2019-09-27 13:42:33
# 1954  2019-09-24 15:13:57  2019-09-27 13:42:08
# 1955  2019-09-24 15:15:43  2019-09-27 13:42:15

# %%
df[df['id'] == 610] #610]
# Out:
#      index   id fid maker_id checker_id type_id region_id province_id city_id  \
# 595    610  610   0       50         68       3        16          77      14
#
#     status_id                                   name  \
# 595         1  UP Diliman College of Arts & Sciences
#
#                                                address email number  fax  \
# 595  College of Arts and Sciences, UP Diliman Campu...   N/A    N/A  N/A
#
#        longitude    latitude remarks           created_at           updated_at
# 595  121.0692769  14.6492420    None  2019-06-20 16:50:21  2019-09-27 11:33:05

# %%
df[pd.to_datetime(df['updated_at']).apply(lambda x: x.year)==2021]
# Out:
#       index    id fid maker_id checker_id type_id region_id province_id  \
# 41       43    43   0       28          9       1        16          77
# 281     283   283   0       28          9       1        15          73
# 295     297   297   0       28          9       1        13          63
# 349     351   351   0       28          9       1        16          77
# 1386   1450  1450   0       27          8       5         2           7
# 1396   1460  1460   0       27          8       5         6          29
# 2803   5523  5523   0       27          8       5         1           1
# 2804   5524  5524   0       27          8       5         2           7
# 2805   5527  5527   0       27          8       5         7          34
# 2806   5528  5528   0       27          8       5         9          45
# 2807   5530  5530   0       28          9       1         8          40
# 2808   5531  5531   0       28          9       1        15          71
# 2809   5532  5532   0       28          9       1        10          51
# 2810   5533  5533   0       28          9       1         6          29
# 2811   5534  5534   0       28          9       1        11          56
# 2812   5535  5535   0       28          9       1         1           4
# 2813   5536  5536   0       28          9       1         1           4
# 2814   5537  5537   0       28          9       1         1           2
# 2815   5538  5538   0       28          9       1         2           7
# 2816   5539  5539   0       28          9       1         1           4
# 2817   5541  5541   0       28          9       1         3          11
# 2818   5542  5542   0       28          9       1         7          37
# 2819   5546  5546   0       28          9       1         7          38
# 2820   5549  5549   0       28          9       1        11          55
# 2821   5551  5551   0       28          0       1         3          16
# 2822   5552  5552   0       28          0       1         8          39
#
#      city_id status_id                                name  \
# 41        17         1                   Valenzuela Branch
# 281      944         1                       Parang Branch
# 295     1415         1        Gen. Santos (Gaisano) Branch
# 349       12         1   Ortigas Center-Pearl Drive Branch
# 1386     717         1                 Southern Isabela LC
# 1396     380         1                    Camarines Sur LC
# 2803     635         1                     Ilocos Norte LC
# 2804     717         1                 Northern Isabela LC
# 2805     116         1                          Antique LC
# 2806     876         1                   Southern Leyte LC
# 2807     468         1                       Barili Branch
# 2808     139         1                      Lamitan Branch
# 2809    1618         1                       Imelda Branch
# 2810     365         1  Calabanga (Camarines Sur) Agri Hub
# 2811    1003         1                   Balingasag Branch
# 2812    1278         1          Sual (Pangasinan) Agri Hub
# 2813    1251         1                  Bolinao (P) Branch
# 2814     665         1    Sta. Maria (Ilocos Sur) Agri Hub
# 2815     731         1          Echague (Isabela) Agri-Hub
# 2816    1280         1         Umingan (Pangasinan) Branch
# 2817     151         1          Bataan Capitol Branch Lite
# 2818     682         1    Barotac Viejo (Iloilo)  Agri Hub
# 2819    1039         1              Himamaylan Branch Lite
# 2820     984         1  Tangub (Misamis Occidental) Branch
# 2821    1552         2          Masinloc (Zambales) Branch
# 2822     269         2              Tubigon (Bohol) Branch
#
#                                                 address  \
# 41    ARCA North Corporate Center Building #150 F. D...
# 281   Cor. Mangga and Durian Streets, Poblacion 1,  ...
# 295   G/F, Vensu Building, National Highway, General...
# 349   Ground Floor, Tycoon Center Bldg., Pearl Drive...
# 1386  2nd Floor Isabela Trade Center San Fermin, Cau...
# 1396  2/F LBP Building, Panganiban Drive cor. Magsay...
# 2803  Venvi IT Park, Ground Floor, Accenture Bldg.Va...
# 2804  2nd Floor Isabela Trade Center San Fermin, Cau...
# 2805                T.A. Fornier st., San Jose, Antique
# 2806    2nd Floor, ABC Building, Apo Street, Ormoc City
# 2807                            Poblacion, Barili, Cebu
# 2808  Quezon Blvd. corner Angela Street, Barangay Ma...
# 2809  National Highway, Poblacion, Imelda, Zamboanga...
# 2810        Del Carmen Street, Calabanga, Camarines Sur
# 2811  National Highway, Barangay Waterfall, Balingas...
# 2812  Municipal Compound, National Road, Poblacion, ...
# 2813  R & R Building, 196 Prudencio Calado Street, B...
# 2814     Barangay Maynganay Sur, Sta. Maria, Ilocos Sur
# 2815  Echague-Poblacion Road, San Fabian, Echague, I...
# 2816  P. Gomez St. Brgy. Poblacion, Umingan, Pangasinan
# 2817  The Bunker, Capitol Compound, Capitol Road, Ba...
# 2818  Barotac Viejo Trade Center, Zulueta Drive, Bar...
# 2819  GM Building, Rizal Street, Barangay 2, Poblaci...
# 2820  2nd North corner Magsaysay Street, Barangay II...
# 2821  National Highway, Barangay Inhobol, Masinloc, ...
# 2822  B. Cabangbang Avenue, Barangay Potohan, Tubigo...
#
#                                    email  \
# 41         BR_VLNZUELA@mail.landbank.com
# 281          BR_PARANG@mail.landbank.com
# 295     BR_GNSNGAISANO@mail.landbank.com
# 349      BR_ORTIGASCTR@mail.landbank.com
# 1386              lbpisabelalc@yahoo.com
# 1396                lbp_nagalc@yahoo.com
# 2803             ilocosnortelc@gmail.com
# 2804        southern.isabelalc@yahoo.com
# 2805                                None
# 2806           southernleytelc@yahoo.com
# 2807          BR_BARILI@mail.landank.com
# 2808        BR_LAMITAN@mail.landbank.com
# 2809             BR_IMELDA@mail.landbank
# 2810    AGRI_CALABANGA@mail.landbank.com
# 2811     BR_BALINGASAG@mail.landbank.com
# 2812         AGRI_SUAL@mail.landbank.com
# 2813        BR_BOLINAO@mail.landbank.com
# 2814     AGRI_STAMARIA@mail.landbank.com
# 2815      AGRI_ECHAGUE@mail.landbank.com
# 2816        BR_UMINGAN@mail.landbank.com
# 2817  BR_BATAANCAPLITE@mail.landbank.com
# 2818       AGRI_BVIEJO@mail.landbank.com
# 2819     BR_HIMAMAYLAN@mail.landbank.com
# 2820         BR_TANGUB@mail.landbank.com
# 2821       BR_MASINLOC@mail.landbank.com
# 2822        BR_TUBIGON@mail.landbank.com
#
#                                      number                  fax  \
# 41       (02) 8292-1971;8292-3688;8292-0114       (02) 8292-1478
# 281              (064)\t425-0035 / 425-0160             425-0035
# 295   (083)\t887-4896 / 552-6075 / 302-6490  552-6075 / 302-6490
# 349                          (02) 8584-9694       (02) 8584-9692
# 1386            (078) 652 1859, 09088996144       (078) 652-0281
# 1396        (054) 473-3264 / (054) 473-2047       (054) 473-7924
# 2803                         (077) 604-0455        (077)604-0422
# 2804                         (078) 652 0281                 None
# 2805                       (036) 540 - 9556                 None
# 2806                       (053) 561 - 3923                 None
# 2807      (0928) 505-0909 / (0956) 647-4448                 None
# 2808                        (0995) 164-8515                 None
# 2809                         (062) 957-6957                 None
# 2810                        (0917) 560-3019                 None
# 2811                        (0917) 100-2933                 None
# 2812                        (0917) 798-8438                 None
# 2813       (0920) 989-0192 / (075) 540-9642                 None
# 2814                        (0927) 913-9776                 None
# 2815                        (0920) 960-4276                 None
# 2816                        (0917) 793-4938                 None
# 2817                         (047) 237-2129                 None
# 2818                         (033) 337-3632                 None
# 2819                         (034) 388-3777                 None
# 2820                         (088) 531-3113                 None
# 2821                        (0966) 239-5481                 None
# 2822                         (038) 237-2658                 None
#
#                longitude            latitude remarks           created_at  \
# 41    120.98321758320519  14.701266365738643    None  2019-06-18 17:04:37
# 281          124.2268932             7.38543    None  2019-06-19 16:28:45
# 295          125.1842295           6.1160405    None  2019-06-19 16:52:04
# 349          121.0608533          14.5814685    None  2019-06-20 11:09:06
# 1386          121.767341           16.937539    None  2019-06-24 10:22:09
# 1396  123.19981439999992          13.6278548    None  2019-06-24 11:03:15
# 2803          18.1807908         120.5917434    None  2021-01-14 13:46:46
# 2804          121.767341           16.937539    None  2021-01-15 09:40:49
# 2805          10.7451364         121.9374064    None  2021-01-15 09:49:37
# 2806          11.0122532         124.6041615    None  2021-01-15 10:11:22
# 2807         123.5112484          10.1117526    None  2021-02-23 10:01:05
# 2808         122.1366344           6.6568211    None  2021-02-23 10:33:08
# 2809          122.912375           7.6436075    None  2021-02-23 10:55:11
# 2810         123.2122331          13.7073353    None  2021-02-23 11:14:39
# 2811         124.7817839           8.7413957    None  2021-02-23 13:10:14
# 2812         120.0951826           16.065856    None  2021-02-23 13:17:47
# 2813         119.8924053          16.3872303    None  2021-02-23 13:28:26
# 2814         120.4759915          17.3797086    None  2021-02-23 13:47:01
# 2815         121.6835948          16.7163032    None  2021-02-23 14:23:54
# 2816         120.8412704          15.9270359    None  2021-02-23 15:05:36
# 2817          120.527279          14.6759667    None  2021-02-23 15:19:52
# 2818         122.8497443          11.0392085    None  2021-02-26 14:48:01
# 2819         122.9665772          10.2054372    None  2021-02-26 15:17:50
# 2820         123.7500494           8.0635912    None  2021-02-26 15:37:21
# 2821         119.9570529          15.5328227    None  2021-03-05 15:00:45
# 2822         123.9484996           9.9360606    None  2021-03-05 15:11:42
#
#                updated_at
# 41    2021-03-05 09:11:25
# 281   2021-03-05 09:45:45
# 295   2021-03-05 09:41:07
# 349   2021-03-05 09:05:08
# 1386  2021-03-23 10:13:56
# 1396  2021-03-23 10:13:49
# 2803  2021-03-23 10:14:10
# 2804  2021-03-23 10:14:03
# 2805  2021-03-23 10:13:40
# 2806  2021-03-23 10:13:34
# 2807  2021-02-23 10:09:03
# 2808  2021-03-05 09:33:20
# 2809  2021-03-05 09:31:46
# 2810  2021-03-05 09:10:20
# 2811  2021-03-05 09:06:27
# 2812  2021-03-05 09:14:36
# 2813  2021-03-05 09:58:43
# 2814  2021-03-05 08:56:44
# 2815  2021-03-05 09:40:43
# 2816  2021-03-05 09:42:54
# 2817  2021-03-05 14:12:14
# 2818  2021-03-05 09:13:38
# 2819  2021-03-05 09:35:47
# 2820  2021-03-05 09:39:18
# 2821  2021-03-05 15:00:45
# 2822  2021-03-05 15:11:42

# %%
earth_radius = 6371000 # in m
test_radius = 50   # in m 

long = np.pi/180*df['longitude'].astype(float)
lat = np.pi/180*df['latitude'].astype(float)
X = [xy for xy in zip(long, lat)]
tree = BallTree(X, metric='haversine')              
dist, ind = tree.query(X, k=20)                
#dist, ind = tree.query_radius(X, r=test_radius/earth_radius, return_distance=True)

# %%
# j =  595
# nearby(ind, dist, df, j)

# %% [markdown]
# # FUNCTIONS

# %%
def vor_geom_calc(city_boundary,join): #This function generates the voronoi regions
    global vor
    global lb_coords
    city_boundary_shape = cascaded_union(city_boundary.geometry)
    lb_coords = gv.points_to_coords(join.geometry)
    vor = gv.voronoi_regions_from_coords(lb_coords, city_boundary_shape)

def plot_vor(z,s): # This function plots the voronoi regions
    test_df = pd.DataFrame([z[0]]).T
    test_df
    test_gpd = gpd.GeoDataFrame(test_df,geometry=0)
    fig, ax = plt.subplots(figsize=(12, 12))
    test_gpd.plot(ax=ax, cmap = 'Blues')
    s.plot(ax=ax, color = 'black', markersize = 0.2)
    plt.rcParams.update({'font.size': 13})
    # plt.xlabel('Latitude ($^{\circ}$)')
    # plt.ylabel('Longitude ($^{\circ}$)')

def overlay(city_boundary,geo_df,join): #This functons overlays data points on to the map to ensure obedience to boundaries
    city_boundary = city_boundary.to_crs(epsg=4326)
    geo_df = geo_df.to_crs(city_boundary.crs)
    gpd.GeoDataFrame(city_boundary)
    overlay(city_boundary,geo_df)
    
def map_plot(city_boundary, boundary): #This function plots the overlain points on the map
    fig, ax = plt.subplots(figsize=(12,12))
    city_boundary.plot(ax=ax, color="gray")
    xmin, ymin, xmax, ymax = boundary.total_bounds
    join.cx[xmin:xmax,ymin:ymax].plot(ax=ax, markersize=0.8, color="black", label ="ATM Branch")
    plt.axis('equal')
    plt.legend(loc='lower right')
    # plt.title('LandBank Branches')
    # plt.xlabel('Latitude ($^{\circ}$)')
    # plt.ylabel('Longitude ($^{\circ}$)')
    plt.show()

def vor_area_calc(area_df,vor): #This function calculates the area of each polygon
    vor_geom = []
    if len(vor[0])>3:
        for i in range(len(vor[0])):
            vor_geom.append(vor[0][i])
        area_df['geometry']=vor_geom
    elif len(vor[0])==3:
        for i in range(3):
            vor_geom.append(vor[0][i])
        area_df['geometry']=vor_geom
    elif len(vor[0])==2:
        for i in range(2):
            vor_geom.append(vor[0][i])
        area_df['geometry']=vor_geom
    elif len(vor[0])==1:
        for i in range(1):
            vor_geom.append(vor[0][i])
        area_df['geometry']=vor_geom
    elif len(vor[0])==0:
        print('No branches in this area')


def area_plot(area_df): #This function plots a histogram of the areas of voronoi regions
    plt.hist(area_df['area'], color = 'red')
    plt.ylabel("Frequency")
    plt.xlabel("Tessellation areas [km\u00b2]")
    # plt.title("Histogram of Voronoi Region Areas")
    plt.show()

def distance_hist(distances): #This function plots a histogram of the distances between points and nearest voronoi centroid
    plt.hist(distances, bins=10, color = 'red')
    plt.xlabel("Next nearest centroid distances [m]")
    plt.ylabel("Frequency")
    # plt.title("Histogram of distance between every Landbank ATM branch and nearest Voronoi centroid")
    plt.show()

def hist2d(centroid_distances): #This function plots a 2d histogram of the distances between points and nearest voronoi centroid to the voronoi region areas
    plt.hist2d(area_df['area'], centroid_distances, bins =[30, 30], cmap='Reds')
    # plt.title("2D Histogram of Centroid Distances and Voronoi Areas")
    plt.colorbar(label='Frequency')
    plt.ylabel('Centroid to Branch Distances [m]') 
    plt.xlabel('Tessellation Areas[km\u00b2]') 
    plt.show()

def centroid_hist(centroid_distances): #This function plots a histogram of the distances between voronoi centroids and nearest point
    plt.hist(centroid_distances, bins=10, color = 'red')
    plt.xlabel("Distance between next nearest centroid and Landbank branch [m]")
    plt.ylabel("Frequency")
    # plt.title("Histogram of distance between nearest Voronoi centroid and every Landbank ATM branch")

def jointplot(area_df,centroid_distances): #This functions plots a 2d joint plot (histogram) of the distances between points and nearest voronoi centroid to the voronoi region areas
    ax = sns.jointplot(x=area_df["area"], y=centroid_distances, kind='hex', cmap = 'Reds', color = 'r')
    plt.xlabel('Tessellation Areas[km\u00b2]')
    plt.ylabel("Vornoid Centroid to Branch Distances [m]")
    plt.colorbar(label='Frequency',orientation="vertical")
    plt.show()

def frac_calc(distances,lim): #This function calculates the percentage of points which are less than or equal to 500 meters away from a Voronoi centroid
    fraction = 0
    count = 0
    for i in range(len(distances)):
        if distances[i] <= lim:
            count+=1
    fraction = round((count/len(distances)*100),2)
    print(fraction,"% of the branches are less than or equal to", lim, "meters away from a centroid.")

def min_dist(dist_matrix): #This function gets the nearest neighbor across the entire dist matrix pairings
    global distances
    global centroid_distances
    distances = []
    centroid_distances = []
    trans = dist_matrix.T
    for i in range(len(join)):
        val = trans[i].min()
        distances.append(val)
    for i in range(len(vor[0])):
        c_val = dist_matrix[i].min()
        centroid_distances.append(c_val)

def dist_matrix_calc(join, area_df): #This function generates a distance matrix across all voronoi centroid-branch point pars
    global dist_matrix
    global branches
    global centroids
    branches = pd.DataFrame()
    centroids = pd.DataFrame()
    centroid = area_df['geometry'].centroid
    join.crs = 'epsg:4326'
    join= join.to_crs(epsg = 3857)
    branches['X'] = join['geometry'].x
    branches['Y'] = join['geometry'].y
    branches.reset_index(drop=True, inplace=True) #created x,y dataframes epsg:3857
    centroids['X'] = centroid.x
    centroids['Y'] = centroid.y
    centroids.reset_index(drop=True, inplace=True) #created x,y dataframes epsg:3857
    branches_array = branches[["X", "Y"]].to_numpy()
    centroids_array = centroids[["X", "Y"]].to_numpy()
    d = cdist(branches_array, centroids_array, 'euclidean')
    dist_matrix = pd.DataFrame(d)

def ccdf(x,label):
    data = x
    data_sorted = np.sort(data)
    p = 1. * np.arange(len(data))/(len(data)-1)
    fig = plt.figure()
    plt.plot(data_sorted,p, color = 'red')
    plt.ylabel('CDF')
    plt.xlabel(label)
    plt.yscale('log')
    plt.xscale('log')
    plt.gca().invert_yaxis()
    plt.gca().set_aspect('equal', adjustable='box')




    
#FURTHER INIT
area_df=gpd.GeoDataFrame()


x_pts = [2.0,3.8,5.0,7.7,8.0]
y_pts = [2.0,8.2,5.0,2.4,7.6]

gpd.points_from_xy(x_pts,y_pts)
geom = gpd.points_from_xy(x_pts,y_pts)
gpd.GeoDataFrame(geometry=geom)
s = gpd.GeoDataFrame(geometry=geom)

box = Polygon([(0,0),(0,10),(10,10),(10,0),(0,0)])
coords = gv.points_to_coords(s.geometry)
z = gv.voronoi_regions_from_coords(coords, box)

# %% [markdown]
# # VORONOI ANALYSIS

# %%
boundary = gpd.read_file("ph1.shp")
city_boundary = boundary.loc[[46],'geometry']
join = gpd.sjoin(geo_df, gpd.GeoDataFrame(city_boundary), op='within')
join = join.drop(columns=['index_right'])

poly = unary_union(city_boundary.iloc[0])
ncr_index = np.argmax([x.area for x in poly])
ncr_shp = poly[ncr_index]
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\_shim.pyx:83, in fiona._shim.gdal_open_vector()
#
# File fiona\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ph1.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# d:\Elmo\OneDrive\Documents\Acads\Physics\21-22 2S\Thesis\LandBank\lbp_spp_voronoi.ipynb Cell 22' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Elmo/OneDrive/Documents/Acads/Physics/21-22%202S/Thesis/LandBank/lbp_spp_voronoi.ipynb#ch0000021?line=0'>1</a> boundary = gpd.read_file("ph1.shp")
#       <a href='vscode-notebook-cell:/d%3A/Elmo/OneDrive/Documents/Acads/Physics/21-22%202S/Thesis/LandBank/lbp_spp_voronoi.ipynb#ch0000021?line=1'>2</a> city_boundary = boundary.loc[[46],'geometry']
#       <a href='vscode-notebook-cell:/d%3A/Elmo/OneDrive/Documents/Acads/Physics/21-22%202S/Thesis/LandBank/lbp_spp_voronoi.ipynb#ch0000021?line=2'>3</a> join = gpd.sjoin(geo_df, gpd.GeoDataFrame(city_boundary), op='within')
#
# File C:\ProgramData\Anaconda3\envs\ox\lib\site-packages\geopandas\io\file.py:201, in _read_file(filename, bbox, mask, rows, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=197'>198</a>     reader = fiona.open
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=199'>200</a> with fiona_env():
# --> <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=200'>201</a>     with reader(path_or_bytes, **kwargs) as features:
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=201'>202</a>
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=202'>203</a>         # In a future Fiona release the crs attribute of features will
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=203'>204</a>         # no longer be a dict, but will behave like a dict. So this should
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=204'>205</a>         # be forwards compatible
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=205'>206</a>         crs = (
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=206'>207</a>             features.crs["init"]
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=207'>208</a>             if features.crs and "init" in features.crs
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=208'>209</a>             else features.crs_wkt
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=209'>210</a>         )
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/geopandas/io/file.py?line=211'>212</a>         # handle loading the bounding box
#
# File C:\ProgramData\Anaconda3\envs\ox\lib\site-packages\fiona\env.py:408, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/env.py?line=404'>405</a> @wraps(f)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/env.py?line=405'>406</a> def wrapper(*args, **kwargs):
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/env.py?line=406'>407</a>     if local._env:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/env.py?line=407'>408</a>         return f(*args, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/env.py?line=408'>409</a>     else:
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/env.py?line=409'>410</a>         if isinstance(args[0], str):
#
# File C:\ProgramData\Anaconda3\envs\ox\lib\site-packages\fiona\__init__.py:264, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/__init__.py?line=260'>261</a>     path = parse_path(fp)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/__init__.py?line=262'>263</a> if mode in ('a', 'r'):
# --> <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/__init__.py?line=263'>264</a>     c = Collection(path, mode, driver=driver, encoding=encoding,
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/__init__.py?line=264'>265</a>                    layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/__init__.py?line=265'>266</a> elif mode == 'w':
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/__init__.py?line=266'>267</a>     if schema:
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/__init__.py?line=267'>268</a>         # Make an ordered dict of schema properties.
#
# File C:\ProgramData\Anaconda3\envs\ox\lib\site-packages\fiona\collection.py:162, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/collection.py?line=159'>160</a> if self.mode == 'r':
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/collection.py?line=160'>161</a>     self.session = Session()
# --> <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/collection.py?line=161'>162</a>     self.session.start(self, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/collection.py?line=162'>163</a> elif self.mode in ('a', 'w'):
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/ox/lib/site-packages/fiona/collection.py?line=163'>164</a>     self.session = WritingSession()
#
# File fiona\ogrext.pyx:540, in fiona.ogrext.Session.start()
#
# File fiona\_shim.pyx:90, in fiona._shim.gdal_open_vector()
#
# DriverError: ph1.shp: No such file or directory

# %%
ncr_boundary = gpd.GeoSeries(ncr_shp)

# %%
# ncr_boundary.to_crs(geo_df.crs)
# join = gpd.sjoin(geo_df, gpd.GeoDataFrame(ncr_boundary), op='within') # if cities
# join = join.drop(columns=['index_right'])

# %%
map_plot(ncr_boundary,boundary)

# %%
vor_geom_calc(ncr_boundary,join)
plot_vor(vor,join)
# Out:
# C:\Users\elmo\AppData\Local\Temp\ipykernel_13304\2596246727.py:4: ShapelyDeprecationWarning: The 'cascaded_union()' function is deprecated. Use 'unary_union()' instead.
#   city_boundary_shape = cascaded_union(city_boundary.geometry)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\elmo\Downloads\LandBank\LandBank\lbp_spp_voronoi.ipynb Cell 26' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/elmo/Downloads/LandBank/LandBank/lbp_spp_voronoi.ipynb#ch0000025?line=0'>1</a> vor_geom_calc(ncr_boundary,join)
#       <a href='vscode-notebook-cell:/c%3A/Users/elmo/Downloads/LandBank/LandBank/lbp_spp_voronoi.ipynb#ch0000025?line=1'>2</a> plot_vor(vor,join)
#
# c:\Users\elmo\Downloads\LandBank\LandBank\lbp_spp_voronoi.ipynb Cell 20' in vor_geom_calc(city_boundary, join)
#       <a href='vscode-notebook-cell:/c%3A/Users/elmo/Downloads/LandBank/LandBank/lbp_spp_voronoi.ipynb#ch0000019?line=3'>4</a> city_boundary_shape = cascaded_union(city_boundary.geometry)
#       <a href='vscode-notebook-cell:/c%3A/Users/elmo/Downloads/LandBank/LandBank/lbp_spp_voronoi.ipynb#ch0000019?line=4'>5</a> lb_coords = gv.points_to_coords(join.geometry)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/elmo/Downloads/LandBank/LandBank/lbp_spp_voronoi.ipynb#ch0000019?line=5'>6</a> vor = gv.voronoi_regions_from_coords(lb_coords, city_boundary_shape)
#
# File C:\ProgramData\Anaconda3\envs\geo_env\lib\site-packages\geovoronoi\_voronoi.py:206, in voronoi_regions_from_coords(coords, geo_shape, per_geom, return_unassigned_points, results_per_geom, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=203'>204</a> # generate Voronoi region polygons and region -> points mapping
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=204'>205</a> logger.info('generating Voronoi region polygons')
# --> <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=205'>206</a> geom_polys, geom_pts = region_polygons_from_voronoi(vor, geom, return_point_assignments=True, **kwargs)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=207'>208</a> # point indices in `geom_pts` refer to `coords[pts_in_geom]` -> map them back to original point indices
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=208'>209</a> pts_in_geom_arr = np.asarray(pts_in_geom)
#
# File C:\ProgramData\Anaconda3\envs\geo_env\lib\site-packages\geovoronoi\_voronoi.py:368, in region_polygons_from_voronoi(vor, geom, return_point_assignments, bounds_buf_factor, diff_topo_error_buf_factor)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=364'>365</a>         isects.append(isect)
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=366'>367</a> if len(isects) == 0:
# --> <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=367'>368</a>     raise RuntimeError('ridge line must intersect with surrounding geometry from `geom`; '
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=368'>369</a>                        'this error often arises when there are points outside of the '
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=369'>370</a>                        'surrounding geometries; first check if all your points are inside '
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=370'>371</a>                        'the surrounding geometries')
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=371'>372</a> elif len(isects) == 1:   # one intersection
#     <a href='file:///c%3A/ProgramData/Anaconda3/envs/geo_env/lib/site-packages/geovoronoi/_voronoi.py?line=372'>373</a>     far_pt = isects[0]
#
# RuntimeError: ridge line must intersect with surrounding geometry from `geom`; this error often arises when there are points outside of the surrounding geometries; first check if all your points are inside the surrounding geometries

# %%
vor_area_calc(area_df,vor)

# %%
#We convert the areas to epsg 3857 to yield areas in sq. km
test = area_df.copy()
test.crs = 'epsg:4326'
test= test.to_crs(epsg = 3857)
test.crs
area_df = test
area_df["area"] = area_df['geometry'].area/ 10**6 #now to km^2

# %%
area_plot(area_df)

# %%
dist_matrix_calc(join,area_df)

# %%
dist_matrix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 dist_matrix
#
# NameError: name 'dist_matrix' is not defined

# %%
min_dist(dist_matrix)

# %%
distance_hist(distances)

# %%
hist2d(centroid_distances)

# %%
centroid_distances_km = [val/1000 for val in centroid_distances]

# %%
centroid_hist(centroid_distances_km)

# %%
centroid_peak,centroidx,_ = plt.hist(centroid_distances_km);
centroid_peak = centroid_peak.max()
centroid_peak

# %%
area_peak,areax,_ = plt.hist(area_df['area'])
area_peak = area_peak.max()
area_peak

# %%
# jointplot(area_df,centroid_distances)
data = pd.DataFrame(
    {
        'Tessellation areas [km\u00b2]': area_df['area'],
        'Centroid to next nearest neighbor distances [km]': centroid_distances_km,
    }
)
ax = sns.jointplot(x='Tessellation areas [km\u00b2]', y='Centroid to next nearest neighbor distances [km]', data = data, 
kind='hist', cmap = 'Reds', color = 'r',cbar=True, bins = (10,10))
plt.subplots_adjust(left=0.1, right=0.8, top=0.9, bottom=0.1)
# get the current positions of the joint ax and the ax for the marginal x
pos_joint_ax = ax.ax_joint.get_position()
pos_marg_x_ax = ax.ax_marg_x.get_position()
# reposition the joint ax so it has the same width as the marginal x ax
ax.ax_joint.set_position([pos_joint_ax.x0, pos_joint_ax.y0, pos_marg_x_ax.width, pos_joint_ax.height])
# reposition the colorbar using new x positions and y positions of the joint ax
ax.fig.axes[-1].set_position([.83, pos_joint_ax.y0, .07, pos_joint_ax.height])

# # plt.annotate(f"Y peak: {round(centroid_peak)}\nX peak: {round(area_peak)}",xy=(8,3000),xycoords='data')
# ax.ax_joint.annotate(f"Y peak: {round(centroid_peak)}\nX peak: {round(area_peak)}",
#                     xy=(0.05, 0.95), xycoords='axes fraction',
#                     ha='left', va='center',
#                     bbox={'boxstyle': 'round', 'fc': 'lightgrey', 'ec': 'salmon'})
ax.ax_joint.set_xscale('log')
ax.ax_joint.set_yscale('log')

# ax.ax_joint.set_xticks([100,1000])
# ax.ax_joint.set_yticks([1000])
# plt.title("Quezon City", loc = 'center')
plt.show()

# %%
area_list = area_df['area'].tolist()
len(area_list)

# %%
import scipy.stats
nbins = 30
s = 2
N = 374
bins1 = np.geomspace(min(area_list), max(area_list), nbins)
bins2 = np.geomspace(min(centroid_distances_km), max(centroid_distances_km), nbins)
g = sns.JointGrid(x="Tessellation areas [km\u00b2]", y='Centroid to next nearest neighbor distances [km]', data=data)
g.plot_joint(sns.histplot, bins=[bins1, bins2],cbar = True)
# plot on the marginal axis x
g.ax_marg_x.hist(data['Tessellation areas [km\u00b2]'], bins=bins1)
# plot on the marginal axis x
g.ax_marg_y.hist(data['Centroid to next nearest neighbor distances [km]'], orientation="horizontal", bins=bins2)
# get the current positions of the joint ax and the ax for the marginal x
pos_joint_ax = g.ax_joint.get_position()
pos_marg_x_ax = g.ax_marg_x.get_position()
# reposition the joint ax so it has the same width as the marginal x ax
g.ax_joint.set_position([pos_joint_ax.x0, pos_joint_ax.y0, pos_marg_x_ax.width, pos_joint_ax.height])
# reposition the colorbar using new x positions and y positions of the joint ax
g.fig.axes[-1].set_position([1, pos_joint_ax.y0, .07, pos_joint_ax.height])
g.refline(x="Tessellation areas [km\u00b2]".mean(),color='b')


g.ax_joint.set_xscale('log')
g.ax_joint.set_yscale('log')

# g.ax_joint.set_xticks([100,1000])
# g.ax_joint.set_yticks([1000])


g.ax_joint.set_position([pos_joint_ax])

# %%
lb = lb_coords.tolist()

# %%
lb = pd.DataFrame(lb_coords)

# %%
lb["points"] = lb[0].astype(str) + lb[1].astype(str)

# %%
lb = lb['points'].value_counts().rename_axis('unique_values').reset_index(name='count')

# %%
lb['unique_values']
lb.rename(columns={'unique_values':'points'})

# %%
lb_coords[481]

# %%
lb_coords[480]

# %%
181/2

# %%
len(branches)

# %%
# fig, ax = plt.subplots(figsize = (10,10))
# area_df.plot(column = 'area', ax=ax, cmap = 'Reds_r',legend = True)
# ax.set_title('Tessellation Areas')
# plt.show()

# %%
ccdf(centroid_distances,'Distance between next nearest centroid [m]')

# %%
ccdf(area_df['area'],'Tessellation Areas [km\u00b2]')

# %%
powerlaw.distribution_compare?

# %%
import powerlaw
results = powerlaw.Fit(centroid_distances)
print(results.power_law.alpha)
print(results.power_law.xmin)
R_centroid, p_centroid = results.distribution_compare('power_law', 'lognormal')

# %%
import powerlaw
results = powerlaw.Fit(area_df['area'])
print(results.power_law.alpha)
print(results.power_law.xmin)
R_area, p_area = results.distribution_compare('power_law', 'lognormal')

# %%
fit = powerlaw.Fit(centroid_distances_km,discrete=True, xmax=1000)
ax1 = fit.plot_ccdf(color='r', label=r"Empirical, $x_{max}=1000$")
fit.power_law.plot_ccdf(color='r', linestyle='--', ax=ax1, label=r"Fit, $x_{max}=1000$")
plt.ylabel('CDF')
plt.xlabel('Distance between next nearest centroid [km]')

# %%
powerlaw.plot_ccdf(np.sort(centroid_distances_km),color='red')
plt.ylabel('CDF')
plt.xlabel('Distance between next nearest centroid [km]')
plt.gca().set_aspect('equal', adjustable='box')

# %%
powerlaw.plot_ccdf(np.sort(area_df['area']),color='red')
plt.ylabel('CDF')
plt.xlabel('Tessellation Areas [km\u00b2]')
plt.gca().set_aspect('equal', adjustable='box')

# %%
fit = powerlaw.Fit(area_df['area'], discrete=True)
####
fit.distribution_compare('power_law', 'lognormal')
fig = fit.plot_ccdf(linewidth=3, label='Empirical Data', marker = 'o', linestyle='None')
fit.power_law.plot_ccdf(ax=fig, color='r', linestyle='--', label='Power law fit')
fit.lognormal.plot_ccdf(ax=fig, color='g', linestyle='--', label='Lognormal fit')
####
fig.set_ylabel(u"CDF")
fig.set_xlabel("Tessellation Areas [km\u00b2]")
handles, labels = fig.get_legend_handles_labels()
fig.legend(handles, labels, loc=3)
fig.annotate(f"R: {round(R_area,2)}\np-value: {round(p_area,2)}",
                    xy=(0.72, 0.9), xycoords='axes fraction',
                    ha='left', va='center',
                    bbox={'boxstyle': 'square', 'fc':'white'})



fit = powerlaw.Fit*area_df['Areas']

# %%
#R = ratio first:second distributions
#high p value - can still be part of Null model (do not reject)
#p value - chance that measurement is part of the distribution

# %%
fit = powerlaw.Fit(centroid_distances, discrete=True)
####
fit.distribution_compare('power_law', 'lognormal')
fig = fit.plot_ccdf(linewidth=3, label='Empirical Data', marker = 'o', linestyle='None')
fit.power_law.plot_ccdf(ax=fig, color='r', linestyle='--', label='Power law fit')
fit.lognormal.plot_ccdf(ax=fig, color='g', linestyle='--', label='Lognormal fit')
####
fig.set_ylabel(u"CDF")
fig.set_xlabel("Distance between next nearest centroid [m]")
handles, labels = fig.get_legend_handles_labels()
fig.legend(handles, labels, loc=3)
fig.annotate(f"R: {round(R_centroid,2)}\np-value: {round(p_centroid,2)}",
                    xy=(0.72, 0.9), xycoords='axes fraction',
                    ha='left', va='center',
                    bbox={'boxstyle': 'square', 'fc':'white'})
